# %%
with open("rules.txt") as rules_file:
    rules = rules_file.read()
rules = rules.split("\n[Rules]\n\n")[1]
rules = rules.split("\n")
#rules

# %%
rules = [rule.split(" --> ") for rule in rules]
#rules

# %%
for i in range(0, len(rules)):
    rules[i][0] = rules[i][0].strip().lower()

for i in range(0, rules.count([""])):
    rules.remove([""])
rules, len(rules)
# Out:
# ([['а', 'ɑ'],
#   ['б', 'b'],
#   ['бє', 'bʲɛ'],
#   ['бі', 'bʲi'],
#   ['бь', 'bʲ'],
#   ['бю', 'bʲu'],
#   ['бя', 'bʲɑ'],
#   ['в', 'ʋ'],
#   ['вє', 'ʋʲɛ'],
#   ['ві', 'ʋʲi'],
#   ['вь', 'ʋʲ'],
#   ['вю', 'ʋʲu'],
#   ['вя', 'ʋʲɑ'],
#   ['г', 'ɣ'],
#   ['гє', 'ɣʲɛ'],
#   ['гі', 'ɣʲi'],
#   ['гь', 'ɣʲ'],
#   ['гю', 'ɣʲu'],
#   ['гя', 'ɣʲɑ'],
#   ['ґ', 'ɣ'],
#   ['ґє', 'ɣʲɛ'],
#   ['ґі', 'ɣʲi'],
#   ['ґь', 'ɣʲ'],
#   ['ґю', 'ɣʲu'],
#   ['ґя', 'ɣʲɑ'],
#   ['д', 'd̪'],
#   ['дє', 'dʲɛ'],
#   ['ді', 'dʲi'],
#   ['дь', 'dʲ'],
#   ['дю', 'dʲu'],
#   ['дя', 'dʲɑ'],
#   ['ддє', 'dʲdʲɛ'],
#   ['дді', 'dʲdʲi'],
#   ['ддю', 'dʲdʲu'],
#   ['ддя', 'dʲdʲɑ'],
#   ['дж', 'd͡ʲʒ'],
#   ['джє', 'd͡ʲʒʲɛ'],
#   ['джі', 'd͡ʲʒʲi'],
#   ['джь', 'd͡ʲʒʲ'],
#   ['джю', 'd͡ʲʒʲu'],
#   ['джя', 'd͡ʲʒʲɑ'],
#   ['віджа', 'ʋʲid̪ʒɑ'],
#   ['віджб', 'ʋʲid̪ʒb'],
#   ['віджв', 'ʋʲid̪ʒʋ'],
#   ['віджд', 'ʋʲid̪ʒd̪'],
#   ['віджи', 'ʋʲid̪ʒɨ'],
#   ['віджл', 'ʋʲid̪ʒɫ'],
#   ['віджм', 'ʋʲid̪ʒm'],
#   ['віджу', 'ʋʲid̪ʒu'],
#   ['оджб', 'od̪ʒb'],
#   ['оджв', 'od̪ʒʋ'],
#   ['оджи', 'od̪ʒɨ'],
#   ['оджл', 'od̪ʒɫ'],
#   ['оджм', 'od̪ʒm'],
#   ['наджи', 'n̪ɑd̪ʒɨ'],
#   ['піджб', 'pʲid̪ʒb'],
#   ['піджв', 'pʲid̪ʒʋ'],
#   ['піджи', 'pʲid̪ʒɨ'],
#   ['піджл', 'pʲid̪ʒɫ'],
#   ['піджм', 'pʲid̪ʒm'],
#   ['піджу', 'pʲid̪ʒu'],
#   ['переджи', 'pɛrɛd̪ʒɨ'],
#   ['дз', 'd̪͡z'],
#   ['дзє', 'd̪͡zʲɛ'],
#   ['дзі', 'd̪͡zʲi'],
#   ['дзь', 'd̪͡zʲ'],
#   ['дзю', 'd̪͡zʲu'],
#   ['дзя', 'd̪͡zʲɑ'],
#   ['відз', 'ʋʲid̪z'],
#   ['одзи', 'od̪zɨ'],
#   ['надза', 'n̪ɑd̪zɑ'],
#   ['надзб', 'n̪ɑd̪zb'],
#   ['надзв', 'n̪ɑd̪zʋ'],
#   ['надзві', 'n̪ɑd̪zʋʲi'],
#   ['надзе', 'n̪ɑd̪zɛ'],
#   ['надзо', 'n̪ɑd̪zo'],
#   ['надзу', 'n̪ɑd̪zu'],
#   ['підз', 'pʲid̪z'],
#   ['підзі', 'pʲid̪zʲi'],
#   ['передза', 'pɛrɛd̪zɑ'],
#   ['передзе', 'pɛrɛd̪zɛ'],
#   ['передзи', 'pɛrɛd̪zɨ'],
#   ['передзі', 'pɛrɛd̪zʲi'],
#   ['е', 'ɛ'],
#   ['є', 'jɛ'],
#   ['ж', 'ʒ'],
#   ['жє', 'ʒʲɛ'],
#   ['жі', 'ʒʲi'],
#   ['жь', 'ʒʲ'],
#   ['жю', 'ʒʲu'],
#   ['жя', 'ʒʲɑ'],
#   ['з', 'z'],
#   ['зє', 'zʲɛ'],
#   ['зі', 'zʲi'],
#   ['зь', 'zʲ'],
#   ['зю', 'zʲu'],
#   ['зя', 'zʲɑ'],
#   ['и', 'ɨ'],
#   ['і', 'i'],
#   ['ї', 'ji'],
#   ['й', 'j'],
#   ['к', 'k'],
#   ['кє', 'kʲɛ'],
#   ['кі', 'kʲi'],
#   ['кь', 'kʲ'],
#   ['кю', 'kʲu'],
#   ['кя', 'kʲɑ'],
#   ['л', 'ɫ'],
#   ['лє', 'lʲɛ'],
#   ['лі', 'lʲi'],
#   ['ль', 'lʲ'],
#   ['лю', 'lʲu'],
#   ['ля', 'lʲɑ'],
#   ['ллє', 'lʲlʲɛ'],
#   ['ллі', 'lʲlʲi'],
#   ['ллю', 'lʲlʲu'],
#   ['лля', 'lʲlʲɑ'],
#   ['м', 'm'],
#   ['мє', 'mʲɛ'],
#   ['мі', 'mʲi'],
#   ['мь', 'mʲ'],
#   ['мю', 'mʲu'],
#   ['мя', 'mʲɑ'],
#   ['н', 'n̪'],
#   ['нє', 'ɲɛ'],
#   ['ні', 'ɲi'],
#   ['нь', 'ɲ'],
#   ['ню', 'ɲu'],
#   ['ня', 'ɲɑ'],
#   ['ннє', 'ɲɲɛ'],
#   ['нні', 'ɲɲi'],
#   ['нню', 'ɲɲu'],
#   ['ння', 'ɲɲɑ'],
#   ['о', 'o'],
#   ['п', 'p'],
#   ['пє', 'pʲɛ'],
#   ['пі', 'pʲi'],
#   ['пь', 'pʲ'],
#   ['пю', 'pʲu'],
#   ['пя', 'pʲɑ'],
#   ['р', 'r'],
#   ['рє', 'rʲɛ'],
#   ['рі', 'rʲi'],
#   ['рь', 'rʲ'],
#   ['рю', 'rʲu'],
#   ['ря', 'rʲɑ'],
#   ['с', 's'],
#   ['сє', 'sʲɛ'],
#   ['сі', 'sʲi'],
#   ['сь', 'sʲ'],
#   ['сю', 'sʲu'],
#   ['ся', 'sʲɑ'],
#   ['ссє', 'sʲsʲɛ'],
#   ['ссі', 'sʲsʲi'],
#   ['ссю', 'sʲsʲu'],
#   ['сся', 'sʲsʲɑ'],
#   ['т', 't̪'],
#   ['тє', 'tʲɛ'],
#   ['ті', 'tʲi'],
#   ['ть', 'tʲ'],
#   ['тю', 'tʲu'],
#   ['тя', 'tʲɑ'],
#   ['ттє', 'tʲtʲɛ'],
#   ['тті', 'tʲtʲi'],
#   ['ттю', 'tʲtʲu'],
#   ['ття', 'tʲtʲɑ'],
#   ['у', 'u'],
#   ['ф', 'f'],
#   ['фє', 'fʲɛ'],
#   ['фі', 'fʲi'],
#   ['фь', 'fʲ'],
#   ['фю', 'fʲu'],
#   ['фя', 'fʲɑ'],
#   ['х', 'x'],
#   ['хє', 'xʲɛ'],
#   ['хі', 'xʲi'],
#   ['хь', 'xʲ'],
#   ['хю', 'xʲu'],
#   ['хя', 'xʲɑ'],
#   ['ц', 't̪͡s'],
#   ['цє', 't̪͡sʲɛ'],
#   ['ці', 't̪͡sʲi'],
#   ['ць', 't̪͡sʲ'],
#   ['цю', 't̪͡sʲu'],
#   ['ця', 't̪͡sʲɑ'],
#   ['ч', 't͡ʲʃ'],
#   ['чє', 't͡ʲʃʲɛ'],
#   ['чі', 't͡ʲʃʲi'],
#   ['чь', 't͡ʲʃʲ'],
#   ['чю', 't͡ʲʃʲu'],
#   ['чя', 't͡ʲʃʲɑ'],
#   ['ш', 'ʃ'],
#   ['шє', 'ʃʲɛ'],
#   ['ші', 'ʃʲi'],
#   ['шь', 'ʃʲ'],
#   ['шю', 'ʃʲu'],
#   ['шя', 'ʃʲɑ'],
#   ['щ', 'ʃt͡ʲʃ'],
#   ['щє', 'ʃt͡ʲʃʲɛ'],
#   ['щі', 'ʃt͡ʲʃʲi'],
#   ['щь', 'ʃt͡ʲʃʲ'],
#   ['щю', 'ʃt͡ʲʃʲu'],
#   ['щя', 'ʃt͡ʲʃʲɑ'],
#   ['ь', ''],
#   ['ю', 'ju'],
#   ['я', 'jɑ'],
#   ['а', 'ɑ'],
#   ['б', 'b'],
#   ['бє', 'bʲɛ'],
#   ['бі', 'bʲi'],
#   ['бь', 'bʲ'],
#   ['бю', 'bʲu'],
#   ['бя', 'bʲɑ'],
#   ['в', 'ʋ'],
#   ['вє', 'ʋʲɛ'],
#   ['ві', 'ʋʲi'],
#   ['вь', 'ʋʲ'],
#   ['вю', 'ʋʲu'],
#   ['вя', 'ʋʲɑ'],
#   ['г', 'ɣ'],
#   ['гє', 'ɣʲɛ'],
#   ['гі', 'ɣʲi'],
#   ['гь', 'ɣʲ'],
#   ['гю', 'ɣʲu'],
#   ['гя', 'ɣʲɑ'],
#   ['ґ', 'ɣ'],
#   ['ґє', 'ɣʲɛ'],
#   ['ґі', 'ɣʲi'],
#   ['ґь', 'ɣʲ'],
#   ['ґю', 'ɣʲu'],
#   ['ґя', 'ɣʲɑ'],
#   ['д', 'd̪'],
#   ['дє', 'dʲɛ'],
#   ['ді', 'dʲi'],
#   ['дь', 'dʲ'],
#   ['дю', 'dʲu'],
#   ['дя', 'dʲɑ'],
#   ['дж', 'd͡ʲʒ'],
#   ['джє', 'd͡ʲʒʲɛ'],
#   ['джі', 'd͡ʲʒʲi'],
#   ['джь', 'd͡ʲʒʲ'],
#   ['джю', 'd͡ʲʒʲu'],
#   ['джя', 'd͡ʲʒʲɑ'],
#   ['віджа', 'ʋʲid̪ʒɑ'],
#   ['віджб', 'ʋʲid̪ʒb'],
#   ['віджв', 'ʋʲid̪ʒʋ'],
#   ['віджд', 'ʋʲid̪ʒd̪'],
#   ['віджи', 'ʋʲid̪ʒɨ'],
#   ['віджл', 'ʋʲid̪ʒɫ'],
#   ['віджм', 'ʋʲid̪ʒm'],
#   ['віджу', 'ʋʲid̪ʒu'],
#   ['оджб', 'od̪ʒb'],
#   ['оджв', 'od̪ʒʋ'],
#   ['оджи', 'od̪ʒɨ'],
#   ['оджл', 'od̪ʒɫ'],
#   ['оджм', 'od̪ʒm'],
#   ['наджи', 'n̪ɑd̪ʒɨ'],
#   ['піджб', 'pʲid̪ʒb'],
#   ['піджв', 'pʲid̪ʒʋ'],
#   ['піджи', 'pʲid̪ʒɨ'],
#   ['піджл', 'pʲid̪ʒɫ'],
#   ['піджм', 'pʲid̪ʒm'],
#   ['піджу', 'pʲid̪ʒu'],
#   ['переджи', 'pɛrɛd̪ʒɨ'],
#   ['дз', 'd̪͡z'],
#   ['дзє', 'd̪͡zʲɛ'],
#   ['дзі', 'd̪͡zʲi'],
#   ['дзь', 'd̪͡zʲ'],
#   ['дзю', 'd̪͡zʲu'],
#   ['дзя', 'd̪͡zʲɑ'],
#   ['відз', 'ʋʲid̪z'],
#   ['одзи', 'od̪zɨ'],
#   ['надза', 'n̪ɑd̪zɑ'],
#   ['надзб', 'n̪ɑd̪zb'],
#   ['надзв', 'n̪ɑd̪zʋ'],
#   ['надзві', 'n̪ɑd̪zʋʲi'],
#   ['надзе', 'n̪ɑd̪zɛ'],
#   ['надзо', 'n̪ɑd̪zo'],
#   ['надзу', 'n̪ɑd̪zu'],
#   ['підз', 'pʲid̪z'],
#   ['підзі', 'pʲid̪zʲi'],
#   ['передза', 'pɛrɛd̪zɑ'],
#   ['передзе', 'pɛrɛd̪zɛ'],
#   ['передзи', 'pɛrɛd̪zɨ'],
#   ['передзі', 'pɛrɛd̪zʲi'],
#   ['е', 'ɛ'],
#   ['є', 'jɛ'],
#   ['ж', 'ʒ'],
#   ['жє', 'ʒʲɛ'],
#   ['жі', 'ʒʲi'],
#   ['жь', 'ʒʲ'],
#   ['жю', 'ʒʲu'],
#   ['жя', 'ʒʲɑ'],
#   ['з', 'z'],
#   ['зє', 'zʲɛ'],
#   ['зі', 'zʲi'],
#   ['зь', 'zʲ'],
#   ['зю', 'zʲu'],
#   ['зя', 'zʲɑ'],
#   ['и', 'ɨ'],
#   ['і', 'i'],
#   ['ї', 'ji'],
#   ['й', 'j'],
#   ['к', 'k'],
#   ['кє', 'kʲɛ'],
#   ['кі', 'kʲi'],
#   ['кь', 'kʲ'],
#   ['кю', 'kʲu'],
#   ['кя', 'kʲɑ'],
#   ['л', 'ɫ'],
#   ['лє', 'lʲɛ'],
#   ['лі', 'lʲi'],
#   ['ль', 'lʲ'],
#   ['лю', 'lʲu'],
#   ['ля', 'lʲɑ'],
#   ['ллє', 'lʲlʲɛ'],
#   ['ллі', 'lʲlʲi'],
#   ['ллю', 'lʲlʲu'],
#   ['лля', 'lʲlʲɑ'],
#   ['м', 'm'],
#   ['мє', 'mʲɛ'],
#   ['мі', 'mʲi'],
#   ['мь', 'mʲ'],
#   ['мю', 'mʲu'],
#   ['мя', 'mʲɑ'],
#   ['н', 'n̪'],
#   ['нє', 'ɲɛ'],
#   ['ні', 'ɲi'],
#   ['нь', 'ɲ'],
#   ['ню', 'ɲu'],
#   ['ня', 'ɲɑ'],
#   ['о', 'o'],
#   ['п', 'p'],
#   ['пє', 'pʲɛ'],
#   ['пі', 'pʲi'],
#   ['пь', 'pʲ'],
#   ['пю', 'pʲu'],
#   ['пя', 'pʲɑ'],
#   ['р', 'r'],
#   ['рє', 'rʲɛ'],
#   ['рі', 'rʲi'],
#   ['рь', 'rʲ'],
#   ['рю', 'rʲu'],
#   ['ря', 'rʲɑ'],
#   ['с', 's'],
#   ['сє', 'sʲɛ'],
#   ['сі', 'sʲi'],
#   ['сь', 'sʲ'],
#   ['сю', 'sʲu'],
#   ['ся', 'sʲɑ'],
#   ['т', 't̪'],
#   ['тє', 'tʲɛ'],
#   ['ті', 'tʲi'],
#   ['ть', 'tʲ'],
#   ['тю', 'tʲu'],
#   ['тя', 'tʲɑ'],
#   ['у', 'u'],
#   ['ф', 'f'],
#   ['фє', 'fʲɛ'],
#   ['фі', 'fʲi'],
#   ['фь', 'fʲ'],
#   ['фю', 'fʲu'],
#   ['фя', 'fʲɑ'],
#   ['х', 'x'],
#   ['хє', 'xʲɛ'],
#   ['хі', 'xʲi'],
#   ['хь', 'xʲ'],
#   ['хю', 'xʲu'],
#   ['хя', 'xʲɑ'],
#   ['ц', 't̪͡s'],
#   ['цє', 't̪͡sʲɛ'],
#   ['ці', 't̪͡sʲi'],
#   ['ць', 't̪͡sʲ'],
#   ['цю', 't̪͡sʲu'],
#   ['ця', 't̪͡sʲɑ'],
#   ['ч', 't͡ʲʃ'],
#   ['чє', 't͡ʲʃʲɛ'],
#   ['чі', 't͡ʲʃʲi'],
#   ['чь', 't͡ʲʃʲ'],
#   ['чю', 't͡ʲʃʲu'],
#   ['чя', 't͡ʲʃʲɑ'],
#   ['ш', 'ʃ'],
#   ['шє', 'ʃʲɛ'],
#   ['ші', 'ʃʲi'],
#   ['шь', 'ʃʲ'],
#   ['шю', 'ʃʲu'],
#   ['шя', 'ʃʲɑ'],
#   ['щ', 'ʃt͡ʲʃ'],
#   ['щє', 'ʃt͡ʲʃʲɛ'],
#   ['щі', 'ʃt͡ʲʃʲi'],
#   ['щь', 'ʃt͡ʲʃʲ'],
#   ['щю', 'ʃt͡ʲʃʲu'],
#   ['щя', 'ʃt͡ʲʃʲɑ'],
#   ['ь', ''],
#   ['ю', 'ju'],
#   ['я', 'jɑ']],
#  396)

# %%
rules_dict = {}
for rule in rules:
    if rules_dict.get(rule[0]) is not None:
        try:
            assert rules_dict[rule[0]] == rule[1]
        except AssertionError:
            print(rule[0], rules_dict[rule[0]], rule[1])
            raise
    rules_dict[rule[0]] = rule[1]
rules_dict
# Out:
# {'а': 'ɑ',
#  'б': 'b',
#  'бє': 'bʲɛ',
#  'бі': 'bʲi',
#  'бь': 'bʲ',
#  'бю': 'bʲu',
#  'бя': 'bʲɑ',
#  'в': 'ʋ',
#  'вє': 'ʋʲɛ',
#  'ві': 'ʋʲi',
#  'вь': 'ʋʲ',
#  'вю': 'ʋʲu',
#  'вя': 'ʋʲɑ',
#  'г': 'ɣ',
#  'гє': 'ɣʲɛ',
#  'гі': 'ɣʲi',
#  'гь': 'ɣʲ',
#  'гю': 'ɣʲu',
#  'гя': 'ɣʲɑ',
#  'ґ': 'ɣ',
#  'ґє': 'ɣʲɛ',
#  'ґі': 'ɣʲi',
#  'ґь': 'ɣʲ',
#  'ґю': 'ɣʲu',
#  'ґя': 'ɣʲɑ',
#  'д': 'd̪',
#  'дє': 'dʲɛ',
#  'ді': 'dʲi',
#  'дь': 'dʲ',
#  'дю': 'dʲu',
#  'дя': 'dʲɑ',
#  'ддє': 'dʲdʲɛ',
#  'дді': 'dʲdʲi',
#  'ддю': 'dʲdʲu',
#  'ддя': 'dʲdʲɑ',
#  'дж': 'd͡ʲʒ',
#  'джє': 'd͡ʲʒʲɛ',
#  'джі': 'd͡ʲʒʲi',
#  'джь': 'd͡ʲʒʲ',
#  'джю': 'd͡ʲʒʲu',
#  'джя': 'd͡ʲʒʲɑ',
#  'віджа': 'ʋʲid̪ʒɑ',
#  'віджб': 'ʋʲid̪ʒb',
#  'віджв': 'ʋʲid̪ʒʋ',
#  'віджд': 'ʋʲid̪ʒd̪',
#  'віджи': 'ʋʲid̪ʒɨ',
#  'віджл': 'ʋʲid̪ʒɫ',
#  'віджм': 'ʋʲid̪ʒm',
#  'віджу': 'ʋʲid̪ʒu',
#  'оджб': 'od̪ʒb',
#  'оджв': 'od̪ʒʋ',
#  'оджи': 'od̪ʒɨ',
#  'оджл': 'od̪ʒɫ',
#  'оджм': 'od̪ʒm',
#  'наджи': 'n̪ɑd̪ʒɨ',
#  'піджб': 'pʲid̪ʒb',
#  'піджв': 'pʲid̪ʒʋ',
#  'піджи': 'pʲid̪ʒɨ',
#  'піджл': 'pʲid̪ʒɫ',
#  'піджм': 'pʲid̪ʒm',
#  'піджу': 'pʲid̪ʒu',
#  'переджи': 'pɛrɛd̪ʒɨ',
#  'дз': 'd̪͡z',
#  'дзє': 'd̪͡zʲɛ',
#  'дзі': 'd̪͡zʲi',
#  'дзь': 'd̪͡zʲ',
#  'дзю': 'd̪͡zʲu',
#  'дзя': 'd̪͡zʲɑ',
#  'відз': 'ʋʲid̪z',
#  'одзи': 'od̪zɨ',
#  'надза': 'n̪ɑd̪zɑ',
#  'надзб': 'n̪ɑd̪zb',
#  'надзв': 'n̪ɑd̪zʋ',
#  'надзві': 'n̪ɑd̪zʋʲi',
#  'надзе': 'n̪ɑd̪zɛ',
#  'надзо': 'n̪ɑd̪zo',
#  'надзу': 'n̪ɑd̪zu',
#  'підз': 'pʲid̪z',
#  'підзі': 'pʲid̪zʲi',
#  'передза': 'pɛrɛd̪zɑ',
#  'передзе': 'pɛrɛd̪zɛ',
#  'передзи': 'pɛrɛd̪zɨ',
#  'передзі': 'pɛrɛd̪zʲi',
#  'е': 'ɛ',
#  'є': 'jɛ',
#  'ж': 'ʒ',
#  'жє': 'ʒʲɛ',
#  'жі': 'ʒʲi',
#  'жь': 'ʒʲ',
#  'жю': 'ʒʲu',
#  'жя': 'ʒʲɑ',
#  'з': 'z',
#  'зє': 'zʲɛ',
#  'зі': 'zʲi',
#  'зь': 'zʲ',
#  'зю': 'zʲu',
#  'зя': 'zʲɑ',
#  'и': 'ɨ',
#  'і': 'i',
#  'ї': 'ji',
#  'й': 'j',
#  'к': 'k',
#  'кє': 'kʲɛ',
#  'кі': 'kʲi',
#  'кь': 'kʲ',
#  'кю': 'kʲu',
#  'кя': 'kʲɑ',
#  'л': 'ɫ',
#  'лє': 'lʲɛ',
#  'лі': 'lʲi',
#  'ль': 'lʲ',
#  'лю': 'lʲu',
#  'ля': 'lʲɑ',
#  'ллє': 'lʲlʲɛ',
#  'ллі': 'lʲlʲi',
#  'ллю': 'lʲlʲu',
#  'лля': 'lʲlʲɑ',
#  'м': 'm',
#  'мє': 'mʲɛ',
#  'мі': 'mʲi',
#  'мь': 'mʲ',
#  'мю': 'mʲu',
#  'мя': 'mʲɑ',
#  'н': 'n̪',
#  'нє': 'ɲɛ',
#  'ні': 'ɲi',
#  'нь': 'ɲ',
#  'ню': 'ɲu',
#  'ня': 'ɲɑ',
#  'ннє': 'ɲɲɛ',
#  'нні': 'ɲɲi',
#  'нню': 'ɲɲu',
#  'ння': 'ɲɲɑ',
#  'о': 'o',
#  'п': 'p',
#  'пє': 'pʲɛ',
#  'пі': 'pʲi',
#  'пь': 'pʲ',
#  'пю': 'pʲu',
#  'пя': 'pʲɑ',
#  'р': 'r',
#  'рє': 'rʲɛ',
#  'рі': 'rʲi',
#  'рь': 'rʲ',
#  'рю': 'rʲu',
#  'ря': 'rʲɑ',
#  'с': 's',
#  'сє': 'sʲɛ',
#  'сі': 'sʲi',
#  'сь': 'sʲ',
#  'сю': 'sʲu',
#  'ся': 'sʲɑ',
#  'ссє': 'sʲsʲɛ',
#  'ссі': 'sʲsʲi',
#  'ссю': 'sʲsʲu',
#  'сся': 'sʲsʲɑ',
#  'т': 't̪',
#  'тє': 'tʲɛ',
#  'ті': 'tʲi',
#  'ть': 'tʲ',
#  'тю': 'tʲu',
#  'тя': 'tʲɑ',
#  'ттє': 'tʲtʲɛ',
#  'тті': 'tʲtʲi',
#  'ттю': 'tʲtʲu',
#  'ття': 'tʲtʲɑ',
#  'у': 'u',
#  'ф': 'f',
#  'фє': 'fʲɛ',
#  'фі': 'fʲi',
#  'фь': 'fʲ',
#  'фю': 'fʲu',
#  'фя': 'fʲɑ',
#  'х': 'x',
#  'хє': 'xʲɛ',
#  'хі': 'xʲi',
#  'хь': 'xʲ',
#  'хю': 'xʲu',
#  'хя': 'xʲɑ',
#  'ц': 't̪͡s',
#  'цє': 't̪͡sʲɛ',
#  'ці': 't̪͡sʲi',
#  'ць': 't̪͡sʲ',
#  'цю': 't̪͡sʲu',
#  'ця': 't̪͡sʲɑ',
#  'ч': 't͡ʲʃ',
#  'чє': 't͡ʲʃʲɛ',
#  'чі': 't͡ʲʃʲi',
#  'чь': 't͡ʲʃʲ',
#  'чю': 't͡ʲʃʲu',
#  'чя': 't͡ʲʃʲɑ',
#  'ш': 'ʃ',
#  'шє': 'ʃʲɛ',
#  'ші': 'ʃʲi',
#  'шь': 'ʃʲ',
#  'шю': 'ʃʲu',
#  'шя': 'ʃʲɑ',
#  'щ': 'ʃt͡ʲʃ',
#  'щє': 'ʃt͡ʲʃʲɛ',
#  'щі': 'ʃt͡ʲʃʲi',
#  'щь': 'ʃt͡ʲʃʲ',
#  'щю': 'ʃt͡ʲʃʲu',
#  'щя': 'ʃt͡ʲʃʲɑ',
#  'ь': '',
#  'ю': 'ju',
#  'я': 'jɑ'}

# %%
len(rules_dict)
# Out:
# 206

# %%
def phonemize(text, mode="ipa"):
    text = text.lower()
    for rule in sorted(rules_dict.keys(), key=len, reverse=True):
        text = text.replace(rule, rules_dict[rule])
    text = text.replace("'", "")
    return text

phonemize("Привіт, як у тебе справи? м'яко падаєм, мякий")
# Out:
# 'prɨʋʲit̪, jɑk u t̪ɛbɛ sprɑʋɨ? mjɑko pɑd̪ɑjɛm, mʲɑkɨj'

# %%
phonemize("ваххабіт оббігав баффало")
# Out:
# 'ʋɑxxɑbʲit̪ obbʲiɣɑʋ bɑffɑɫo'
